# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# data extration 
df = pd.read_csv("C:\\Users\\lenovo\\OneDrive\\Desktop\\Recruiter Performance\\recruiter_performance\\data\\Recruiter Performance.csv")
# print(df.head())

info = df.info()

print(info)

print(df.)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13651 entries, 0 to 13650
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Status                       13651 non-null  str
#  1   Shared Date                  13651 non-null  str
#  2   Client Name                  13641 non-null  str
#  3   Channel                      13640 non-null  str
#  4   Position Name                13645 non-null  str
#  5   Location                     13613 non-null  str
#  6   State                        13602 non-null  str
#  7   Gender                       13525 non-null  str
#  8   Candidate Name               13647 non-null  str
#  9   Contact No.                  13641 non-null  str
#  10  E mail ID                    13530 non-null  str
#  11  Current Company              13488 non-null  str
#  12  Current Designation          13355 non-null  str
# ...
